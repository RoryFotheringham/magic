# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ndlonly_d3 = np.array([61.471559286117554, 15.164979696273804, 13.014830589294434, 2.337695360183716, 61.454972982406616, 15.223514080047607])

ndlonly_d4 = np.array([14.539244174957275, 20.843597650527954, 130.12650632858276, 7.386984586715698, 14.847110748291016, 20.842536449432373])

ndlonly_d5 = np.array([123.59522342681885, 47.341208934783936, 4.1173317432403564, 202.43934178352356, 120.65417981147766, 46.925182819366455])

ndlonly_d6= np.array([72.18792176246643, 876.2719774246216, 1823.0972754955292, 2958.985743522644, 70.66720461845398 ])


ndlonly_means = [np.mean(ndlonly_d3), np.mean(ndlonly_d4), np.mean(ndlonly_d5), np.mean(ndlonly_d6)]

ndlonly_std = [np.std(ndlonly_d3), np.std(ndlonly_d4), np.std(ndlonly_d5), np.std(ndlonly_d6)]




asym_ndl_d3 = np.array([4.998441934585571, 3.8826496601104736, 21.033782482147217, 2.104843854904175, 4.896327257156372, 3.8527112007141113])

asym_ndl_d4 = np.array([82.04593849182129, 96.94890570640564, 4.005739688873291, 12.23444414138794, 81.66008377075195, 97.41531753540039])

asym_ndl_d5 = np.array([40.1849365234375, 34.77399682998657, 75.99318194389343, 756.550794839859,  756.550794839859, 32.81431436538696])

asym_ndl_d6 = np.array([89.62654829025269, 519.22132396698, 1645.268443107605])


asym_ndl_means = [np.mean(asym_ndl_d3), np.mean(asym_ndl_d4), np.mean(asym_ndl_d5), np.mean(asym_ndl_d6)]

asym_ndl_std = [np.std(asym_ndl_d3), np.std(asym_ndl_d4), np.std(asym_ndl_d5), np.std(asym_ndl_d6)]



triv_asym_d3 = np.array([4.1627585887908936, 3.8826496601104736, 4.108906030654907, 11.077296495437622, 0.9733600616455078, 4.316167116165161])

triv_asym_d4 = np.array([3.1032445430755615,  7.621629476547241, 82.41517281532288, 5.95026707649231, 3.0239648818969727, 7.336420059204102])

triv_asym_d5 = np.array([119.86315321922302, 229.64318346977234, 119.86315321922302, 139.47337698936462,  125.33738851547241, 255.766277551651])

triv_asym_d6 = np.array([183.50454950332642, 58.60587286949158, 139.8555281162262, 139.51387858390808,48.92049527168274, 137.62949299812317 ])



triv_asym_means = [np.mean(triv_asym_d3), np.mean(triv_asym_d4), np.mean(triv_asym_d5), np.mean(triv_asym_d6)]

#triv_asym_std = [np.std(asym_ndl_d3), np.std(asym_ndl_d4), np.std(asym_ndl_d5), np.std(asym_ndl_d6)]


base_d3 = np.array([4.171199560165405, 30.158026933670044, 4.8572845458984375, 7.0217108726501465, 3.9364659786224365, 30.04825711250305])

base_d4 = np.array([18.127785205841064,  18.074089765548706, 15.436477422714233, 25.853670597076416, 18.73645806312561, 20.738658905029297])

base_d5 = np.array([70.50838017463684, 13.82032299041748, ])

base_d6 = np.array([13.805579423904419, 13.71729040145874,  4.786416053771973, 4.137774705886841, 13.771907567977905,14.013539791107178 ])

base_means = [np.mean(base_d3), np.mean(base_d4), np.mean(base_d5), np.mean(base_d6)]



depths = ['3', '4', '5', '6']

plt.figure(figsize=(11,7))
plt.plot(depths, base_means, label='baseline')
#plt.plot(depths, triv_asym_means, label='triv_asym')
plt.plot(depths, ndlonly_means, label='base + ndl')
plt.plot(depths, asym_ndl_means, label='base + ndl + triv constraints not in verifier')

plt.xlabel('Trick Depth')
plt.ylabel('Time (seconds)')
plt.legend()
plt.show()
